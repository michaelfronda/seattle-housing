# %%
# bring in libraries 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import sklearn

# %matplotlib inline 

import warnings 
warnings.filterwarnings("ignore")

# %%
filename = "https://library.startlearninglabs.uw.edu/DATASCI410/Datasets/kc_house_data.csv"

df = pd.read_csv(filename)

# %%
print('Top 5 rows\n===============\n')
display(df.head())

print('Random Sample of 5 rows\n===============\n')
display(df.sample(5))

print('Bottom 5 rows\n===============\n')
display(df.tail())
# Out:
# Top 5 rows
# ...
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.sample(6).T
# Out:
#                          18217            3089             14146  \
# id                  1591600506       1823099076       1777600210
# date           20150225T000000  20140820T000000  20150217T000000
# price                 479000.0         495000.0         590000.0
# bedrooms                     4                3                4
# bathrooms                 2.25              2.5             2.25
# sqft_living               2270             1780             2530
# sqft_lot                  9464            47480            10611
# floors                     1.5              2.0              1.0
# waterfront                   0                0                0
# view                         0                0                0
# condition                    4                3                5
# grade                        7                7                8
# sqft_above                1520             1780             1320
# ...

# %% [markdown]
# #### Features
#
# Something important to note is the meaning of each of the features. The following image was taken from the kaggle discussion!
#
#
# <img src="https://storage.googleapis.com/kaggle-forum-message-attachments/479761/11440/Screenshot%202019-02-27%20at%205.26.24%20PM.png">

# %% [markdown]
# ### Clean
#
# - Outliers removal
# - Missing values

# %%
# check for nulls
df.isnull().sum() / len(df)
# Out:
# id               0.0
# date             0.0
# price            0.0
# bedrooms         0.0
# bathrooms        0.0
# sqft_living      0.0
# sqft_lot         0.0
# floors           0.0
# waterfront       0.0
# view             0.0
# condition        0.0
# grade            0.0
# sqft_above       0.0
# sqft_basement    0.0
# yr_built         0.0
# yr_renovated     0.0
# zipcode          0.0
# lat              0.0
# long             0.0
# sqft_living15    0.0
# sqft_lot15       0.0
# dtype: float64

# %%
df.shape 
# 21613 rows 
# 21 columns
# Out:
# (21613, 21)

# %%
numeric = ['price',
 'sqft_living',
 'sqft_lot',
 'sqft_above',
 'sqft_basement',
 'sqft_living15',
 'sqft_lot15']

for col in numeric: 
    plt.figure() 
    sns.boxplot(df[col]);

# %%
def remove_outliers(df, col): 
    high = np.mean(df[col]) + 3 * np.std(df[col])
    low = np.mean(df[col]) - 3 * np.std(df[col])
    flag = (df.loc[:,col] < high) & (df.loc[:,col] > low)
    df.loc[~flag, col] = np.float('NaN') 
    return df 

# cleanse the outliers in the above numeric columns
for col in numeric:
    df = remove_outliers(df, col)

# %%
df.isnull().sum()
# Out:
# id                 0
# date               0
# price            406
# bedrooms           0
# bathrooms          0
# sqft_living      248
# sqft_lot         347
# floors             0
# waterfront         0
# view               0
# condition          0
# grade              0
# sqft_above       254
# sqft_basement    247
# yr_built           0
# yr_renovated       0
# zipcode            0
# lat                0
# long               0
# sqft_living15    237
# sqft_lot15       363
# dtype: int64

# %%
406 / len(df) * 100 # check percentages of highest nans column
# Out:
# 1.8784990514967843

# %%
# less than 2% in the highest columns let's go ahead and drop nans
dfa = df.dropna()

# %% [markdown]
# ## Feature Engineering

# %%
# Binning
for i in range(1,5):
    dfa.loc[dfa.loc[:,'grade'] == i, 'grade'] = 0

for i in range(5,9):
    dfa.loc[dfa.loc[:,'grade'] == i, 'grade'] = 1

for i in range(9,14):
    dfa.loc[dfa.loc[:,'grade'] == i, 'grade'] = 2

dfa.head().T
# Out:
#                              0                1                2  \
# id                  7129300520       6414100192       5631500400
# date           20141013T000000  20141209T000000  20150225T000000
# price                 221900.0         538000.0         180000.0
# bedrooms                     3                3                2
# bathrooms                  1.0             2.25              1.0
# sqft_living             1180.0           2570.0            770.0
# sqft_lot                5650.0           7242.0          10000.0
# floors                     1.0              2.0              1.0
# waterfront                   0                0                0
# view                         0                0                0
# condition                    3                3                3
# grade                        1                1                1
# sqft_above              1180.0           2170.0            770.0
# ...

# %%
##### Feature extraction #####
# fix data
def fix_date(date):
    import re
    clean_date = re.sub('T000000', '', date)
    y = clean_date[:4]
    m = clean_date[4:6]
    d = clean_date[6:]
    return y + '-' + m + '-' + d

dfa['date'] = dfa['date'].apply(lambda x: fix_date(x))

# feature extraction: date 
dfa['year'] = dfa['date'].astype(str).str[:4]
dfa['month'] = dfa['date'].astype(str).str[5:7]
dfa['day'] = dfa['date'].astype(str).str[8:10]

# %%
dfa.head().T
# Out:
#                         0           1           2           3           4
# id             7129300520  6414100192  5631500400  2487200875  1954400510
# date           2014-10-13  2014-12-09  2015-02-25  2014-12-09  2015-02-18
# price            221900.0    538000.0    180000.0    604000.0    510000.0
# bedrooms                3           3           2           4           3
# bathrooms             1.0        2.25         1.0         3.0         2.0
# sqft_living        1180.0      2570.0       770.0      1960.0      1680.0
# sqft_lot           5650.0      7242.0     10000.0      5000.0      8080.0
# floors                1.0         2.0         1.0         1.0         1.0
# waterfront              0           0           0           0           0
# view                    0           0           0           0           0
# condition               3           3           3           5           3
# grade                   1           1           1           1           1
# ...

# %%
# plot long and lat with price
sns.relplot(x='long', y='lat', hue='price', data=dfa, height=7);

# %%
# exploration
plt.figure(figsize=(15,7))
dfa['bathrooms'].value_counts().plot(kind='bar');

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=1)
pc1 = pca.fit_transform(dfa[['long', 'lat']])

# %%
dfa['location'] = pc1

# %%
dfa.sample(5).T
# Out:
#                     5715        18688       7474        17586       9137
# id             4139400280  1919800090  7955040130   326069164  7312200040
# date           2014-10-08  2014-12-15  2014-08-05  2015-04-29  2014-12-16
# price            765000.0    625000.0    460000.0    840000.0    560000.0
# bedrooms                3           4           3           4           4
# bathrooms             2.5        1.75        1.75         2.5         2.5
# sqft_living        2700.0      2410.0      1370.0      3450.0      1790.0
# sqft_lot           8444.0      6770.0      8467.0     43216.0      9787.0
# floors                2.0         1.0         1.0         2.0         1.0
# waterfront              0           0           0           0           0
# view                    0           0           0           0           2
# condition               3           4           4           3           4
# grade                   2           1           1           2           1
# ...

# %%
cols_to_scale = numeric[1:] + ['bedrooms', 'bathrooms', 'floors', 'condition', 'grade']

# %%
def scale(col):
    mean_col = np.mean(col)
    std_col = np.std(col)
    std = (col - mean_col) / std_col
    return std

for col in cols_to_scale:
    dfa[col] = scale(dfa[col])

# %%
dfa.sample(5).T
# Out:
#                     15436       21507       5079        3310        9481
# id             8562891100  7625702441  6873000190  6084200100  3630120880
# date           2014-09-10  2014-08-08  2015-03-11  2014-08-01  2015-02-27
# price            381500.0    377500.0    656000.0    400000.0    780000.0
# bedrooms         0.729919   -0.367953   -1.465825   -0.367953   -0.367953
# bathrooms        0.624086    0.624086    0.624086    0.624086    2.031651
# sqft_living      0.606137   -0.825478    0.394046    0.195211    1.772638
# sqft_lot        -0.383161   -0.778361   -0.704144   -0.536671   -0.382992
# floors           0.956969    2.809388    2.809388    0.956969    0.956969
# waterfront              0           0           0           0           0
# view                    0           0           0           0           0
# condition        0.907106   -0.631572   -0.631572   -0.631572   -0.631572
# grade           -0.436628   -0.436628   -0.436628   -0.436628    2.238737
# ...

# %%
dfa['yr_built'] = dfa['yr_built'].astype(str)
dfa['yr_renovated'] = dfa['yr_renovated'].astype(str)
dfa['zipcode'] = dfa['zipcode'].astype(str)

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model

# %%
X = X[['bedrooms', 'bathrooms', 'floors', 'zipcode', 'view', 'waterfront', 'sqft_living',
      'sqft_lot', 'sqft_basement', 'condition', 'grade']]

# %%
bedrooms
bathrooms
sqft_living
floors
view
condition
grade
sqft_above
yr_built
sqft_living15
sqft_lot15
month
day
location

# %%
X = df[['sqft_above', 'sqft_living15', 'sqft_living', 'sqft_basement', 'bedrooms', 'bathrooms', 'waterfront', 'floors', 'lat', 'view' , 'grade']]

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model


X = dfa.drop(columns = ['id', 'date', 'year', 'price', 'lat', 'long'])
# X = dfa[['bedrooms', 'bathrooms', 'floors', 'zipcode', 'view', 'waterfront', 'sqft_living',
#       'sqft_lot', 'sqft_basement', 'condition', 'grade']]

y = dfa['price'].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, # features
                                                    y, # response 
                                                    test_size = 0.8, # 80/20 Split; Training 80%, Testing 20% 
                                                    random_state = 42) # seeding

# %%
linreg = linear_model.LinearRegression()

linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linreg.coef_
# Out:
# array([-16127.91569452,   1741.72958726,  22681.85616246,    381.19872842,
#         47198.43667869,  12447.85182451, 113092.08414857,  -9383.22078298,
#         19478.5138946 ,  34862.70811912,  64677.82248405])

# %%
pred = linreg.predict(X_test)

# %%
plt.scatter(y_test, pred);

# %%
from sklearn import metrics

# %%
print('R2: {:.4f}'.format(metrics.explained_variance_score(y_test, pred)))
# Out:
# R2: 0.5066

# %%
sns.scatterplot(data=dfa, x="price", y= "sqft_living");

# %%
alpha = 1000 # regularization constant
l1 = linear_model.Lasso(alpha = alpha)
l1.fit(X, y)
# Out:
# Lasso(alpha=1000)

# %%
l1.coef_
# Out:
# array([-1.38874605e+04,  3.03172968e+04,  8.15841640e+04,  0.00000000e+00,
#         2.12625995e+04,  0.00000000e+00,  3.92630988e+04,  1.83891758e+04,
#         5.75428665e+04,  1.26366966e+03,  0.00000000e+00, -1.58020371e+03,
#        -0.00000000e+00,  5.16532128e+04, -1.63084941e+03, -2.30238945e+03,
#        -3.19044294e+02, -4.61955012e+05])

# %%
print('The selected features are for an regularization constant of {}:\n------------------'.format(alpha))
LASSO_feats = []
for coef, feat in zip(l1.coef_, X.columns):
    if coef != 0.0:
        print(feat)
        LASSO_feats.append(feat)
# Out:
# The selected features are for an regularization constant of 1000:
# ------------------
# bedrooms
# bathrooms
# sqft_living
# floors
# view
# condition
# grade
# sqft_above
# yr_built
# sqft_living15
# sqft_lot15
# month
# day
# location

# %%
from sklearn.feature_selection import SelectKBest, f_regression
SelectKBest(score_func = f_regression, k = 8)
# Out:
# SelectKBest(k=8, score_func=<function f_regression at 0x7fddd0424f70>)

# %%
nb_feat = 15 # arbitrary choosen number of features

back_selector_all = RFE(LogR, nb_feat, step = 1, verbose = True) # select num features, removing 1 feature at a time
back_selector_all = back_selector_all.fit(X, y)

# %%
alpha = 0.02 # regularization constant
clf_l = linear_model.Lasso(alpha = alpha)
clf_l.fit(X, y)

# %%
# Experiment: Clusters 
from sklearn import cluster

clusters = list(cluster.KMeans(n_clusters=3).fit(dfa[['price', 'long', 'lat', 'zipcode']]).labels_)

df_test = dfa.copy()

df_test['clusters'] = clusters

sns.relplot(x='long', y='lat', hue='clusters', data=df_test, height=7);

# %%
sns.relplot(x='long', y='lat', hue='zipcode', data=df_test, height=7);

# %%
# from sklearn.feature_extraction import FeatureHasher
# h = FeatureHasher(n_features=3)
# D = [{'dog': 1, 'cat':2, 'elephant':4},{'dog': 2, 'run': 5}]
# f = h.transform(D)
# f.toarray()
# Out:
# array([[ 0.,  0., -4., -1.,  0.,  0.,  0.,  0.,  0.,  2.],
#        [ 0.,  0.,  0., -2., -5.,  0.,  0.,  0.,  0.,  0.]])

# %%
# create correlation object
corr = dfa.corr()

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

plt.subplots(figsize=(25,20))
sns.heatmap(corr, cmap=cmap, annot=True);

# %%
from yellowbrick.regressor import ResidualsPlot

# %%
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
